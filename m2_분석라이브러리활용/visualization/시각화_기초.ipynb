# %% [markdown]
# #### pandas 내장 그래프 도구
# - 판다스는 Matplotlib 라이브러리의 기능을 일부 내장하고 있어서 별도로 임포트하지 않고 간단히 그래프를 그릴 수 있음
# - 선그래프 : df.plot() 메소드를 적용 시 다른 옵션을 추가하지 않으면 기본적인 선 그래프를 그림
# - 막대 그래프 : df.plot(kind='bar'), df.plot(kind='barh',stacked=True, alpha = 0.8)
# - 히스토그램 : df.plot(kind='hist')
# - 산점도 : df.plot(x='',y='',kind='scatter'),상관관계를 볼 수 있음
# - 박스 플롯: df.plot(kind='box'), df.boxplot(column=['feature'])특정 변수의 데이터 분포와 분산 정도에 대한 정보를 제공
#
# #### matplotlib
# - histogram : plt(x,bins=)
# - line plot: plt.plot(x,y)
# - plt.bar(x,y,color='')
# - scatter plot : plt.scatter(x,y)
#
# #### seaborn
# - sns.distplot(data, bins=, color=, kde=)
# - sns.boxplot(x,y,data,color)
# - sns.violinplot(x,y,data,color)
# - sns.barplot(x,y,data,color)
# - sns.joinplot(x,y,data,color)
# - sns.pairplot(data,hue,palette)
# - sns.lmplot(x,y,data,color)
# - sns.regplot(x,y,data,fig_reg=False)

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('./dataset/주가데이터.csv')
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0  2018-07-02  10100   600  10850  10900  10000  137977
# 1  2018-06-29  10700   300  10550  10900   9990  170253
# 2  2018-06-28  10400   500  10900  10950  10150  155769
# 3  2018-06-27  10900   100  10800  11050  10500  133548
# 4  2018-06-26  10800   350  10900  11000  10700   63039

# %%
li = ['Date','Close','Start','High','Low','Volumn']
df.drop('전일종가',axis =1, inplace = True)
df.columns = li
df.head()
# Out:
#          Date  Close  Start   High    Low  Volumn
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volumn  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
# Date를 datetime 으로 변경한 후 인덱스로 셋팅하세요.

# %%
df.Date = pd.to_datetime(df.Date)
df1 = df.set_index('Date')
df1.drop(['Volumn'],axis=1,inplace=True)
df1.head()
# Out:
#             Close  Start   High    Low
# Date
# 2018-07-02  10100  10850  10900  10000
# 2018-06-29  10700  10550  10900   9990
# 2018-06-28  10400  10900  10950  10150
# 2018-06-27  10900  10800  11050  10500
# 2018-06-26  10800  10900  11000  10700

# %%
# 선그래프
df1.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2 = df1.sort_index()
df2.Close.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Q. 6월 데이터만을 추출해서 Close칼럼으로 일별 막대그래프를 표현하세요.

# %%
df2.loc['2018-06'].Close.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df2.Close.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.rename(columns = {'Volumn':'Volume'}, inplace=True)
df.head()
# Out:
#         Date  Close  Start   High    Low  Volume
# 0 2018-07-02  10100  10850  10900  10000  137977
# 1 2018-06-29  10700  10550  10900   9990  170253
# 2 2018-06-28  10400  10900  10950  10150  155769
# 3 2018-06-27  10900  10800  11050  10500  133548
# 4 2018-06-26  10800  10900  11000  10700   63039

# %%
df.Volume.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.Volume.describe()
# Out:
# count        20.000000
# mean     158014.150000
# std      134473.512003
# min       25171.000000
# 25%       58323.250000
# 50%      134176.500000
# 75%      185836.000000
# max      558148.000000
# Name: Volume, dtype: float64

# %%
import seaborn as sns
sns.histplot(df.Volume,kde=True)
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Count'>

# %%
# 산점도
df.plot(x='Close',y='Volume',kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Volume'>

# %%
df.Close.describe()
# Out:
# count       20.000000
# mean     11662.500000
# std        927.060294
# min      10100.000000
# 25%      11087.500000
# 50%      11725.000000
# 75%      11962.500000
# max      13450.000000
# Name: Close, dtype: float64

# %%
# Box plot
df.Close.plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Box plot 의미 해석
# - IQR(Inter Quartile Range) : 제 3사분위수(Q3) - 제1사분위수(Q1)
# - lower whisker: Q1 - 1.5 * IQR 이내인 값 중에서 최솟값
# - upper whisker: Q3 + 1.5 * IQR 이내인 값 중에서 최댓값
# - 이상치 : lower whisker, upper whisker를 벗어나는 값

# %%
df.Close.describe()
# Out:
# count       20.000000
# mean     11662.500000
# std        927.060294
# min      10100.000000
# 25%      11087.500000
# 50%      11725.000000
# 75%      11962.500000
# max      13450.000000
# Name: Close, dtype: float64

# %%
# Q. Close 칼럼의 이상치를 구하세요.
Q1 = df.Close.quantile(.25)
Q3 = df.Close.describe()['75%']
IQR = Q3 - Q1
uw_check = Q3 + 1.5 * IQR
print(uw_check,'\n')
print(df.Close.sort_values(ascending=False)[:5],'\n')
print('uw 13200을 벗어나는 값 선택:')
df.Close.loc[df.Close > Q3 + 1.5 * IQR]
# Out:
# 13275.0
#
# 12    13450
# 11    13400
# 13    13200
# 17    12150
# 10    12000
# Name: Close, dtype: int64
#
# uw 13200을 벗어나는 값 선택:
# 11    13400
# 12    13450
# Name: Close, dtype: int64

# %%
# [과제] Start 칼럼의 분포 및 이상치 여부를 탐색하는 Box Plot 및 이상치를 구하세요.

# %%
df.Start.plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df.Start.describe()
# Out:
# count       20.000000
# mean     11755.000000
# std        865.250192
# min      10550.000000
# 25%      11125.000000
# 50%      11800.000000
# 75%      12050.000000
# max      13600.000000
# Name: Start, dtype: float64

# %%
Q1 = df.Start.quantile(.25)
Q3 = df.Start.describe()['75%']
IQR = Q3 - Q1
uw_check = Q3 + 1.5 * IQR
print(uw_check,'\n')

print(df.Start.sort_values(ascending=False)[:5],'\n')
print('uw 13437을 벗어나는 값 선택:')
df.Start.loc[df.Start > Q3 + 1.5 * IQR]
# Out:
# 13437.5
#
# 11    13600
# 10    13400
# 12    13200
# 16    12200
# 13    12200
# Name: Start, dtype: int64
#
# uw 13437을 벗어나는 값 선택:
# 11    13600
# Name: Start, dtype: int64

# %% [markdown]
# [과제] df_ep 데이터 프레임으로 다음을 수행하세요
# - 선그래프
# - 'south' 칼럼의 막대그래프
# - 'south' 칼럼의 히스토그램
# - box plot

# %%
df = pd.read_excel('./dataset/df_ep.xlsx')
df.set_index('year',inplace=True)
df.head()
# Out:
#       south  north
# year
# 1990   1077    277
# 1991   1186    263
# 1992   1310    247
# 1993   1444    221
# 1994   1650    231

# %%
# 선그래프
df.plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# 'south'칼럼의 막대그래프
df.south.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# 'south'칼럼의 히스토그램
df.south.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# 'south' 칼럼의 Box plot
df.south.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
# [과제] df_auto의 각 칼럼을 시각화해서 탐색한 후 인사이트를 기술하세요(5개 이상)

# %%
df_auto = pd.read_excel('./dataset/auto-mpg.xlsx')
df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df_auto.mpg.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(0)
data = np.arange(50) + np.random.randint(1,10,size=50)
plt.hist(data,bins = 30)
# Out:
# (array([1., 0., 3., 1., 1., 2., 1., 1., 2., 0., 4., 1., 3., 4., 1., 2., 3.,
#         0., 3., 1., 3., 0., 2., 3., 2., 1., 1., 1., 2., 1.]),
#  array([ 2. ,  3.8,  5.6,  7.4,  9.2, 11. , 12.8, 14.6, 16.4, 18.2, 20. ,
#         21.8, 23.6, 25.4, 27.2, 29. , 30.8, 32.6, 34.4, 36.2, 38. , 39.8,
#         41.6, 43.4, 45.2, 47. , 48.8, 50.6, 52.4, 54.2, 56. ]),
#  <BarContainer object of 30 artists>)

# %%
x = np.arange(1,21,2)
y = np.array([3,5,6,13,30,21,22,29,33,32])
plt.figure(figsize=(10,6))
plt.plot(x,y,color='red',marker='o',markersize=5)
plt.xlabel('x',size=20)
plt.ylabel('y',size=20)
plt.legend(labels=['lineplot'])

# %%
import numpy as np
np.random.seed(0)
x = np.arange(20)
y1 = np.arange(20)*2 + np.random.randn(20)*10
y2 = np.arange(20)*2 + np.random.randn(20)

plt.figure(figsize=(10,6))
plt.plot(x,y1)
plt.plot(x,y2,color='magenta',marker='o',markersize=5)
plt.xlabel('x',size=20)
plt.ylabel('y',size=20)
plt.legend(labels=['A','B'])
plt.title('Line Graph',size=30)
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
# 막대그래프
y = np.random.randint(2,19,size=10)
x = range(len(y))
plt.figure(figsize=(10,6))
plt.bar(x,y,width=0.8,color='skyblue')
plt.ylabel('Y')
plt.xlabel('X')
# Out:
# Text(0.5, 0, 'X')

# %%
df = pd.read_csv('./dataset/movie.csv')
df.head()
# Out:
#    targetDt  rank rankOldAndNew   movieCd          movieNm    salesAmt  \
# 0  20180220     1           OLD  20170561            블랙 팬서  1339822000
# 1  20180220     2           OLD  20168250            골든슬럼버   363771900
# 2  20180220     3           OLD  20179205  조선명탐정: 흡혈괴마의 비밀   296896400
# 3  20180220     4           OLD  20176121  흥부: 글로 세상을 바꾼 자   126148600
# 4  20180220     5           OLD  20078561     명탐정 코난:감벽의 관    78434800
#
#    audiCnt
# 0   171158
# 1    48097
# 2    40318
# 3    16991
# 4    11466

# %%
# Q. movie.csv에서 x축을 movieNm ,y축을 salesAmt로 막대그래프를 그리세요.

# %%
import matplotlib as mpl
mpl.rc('font',family='Malgun Gothic')  # 한글 폰트 설정
mpl.rcParams['axes.unicode_minus'] = False    #  마이너스가 나오는 경우 나오도록 처리
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(20,10))
plt.bar(df.movieNm,df.salesAmt,color='skyblue')
plt.title('영화별 총 매출액',size=30)
plt.xlabel('영화이름',size=15)
plt.ylabel('총매출액',size=15)
plt.xticks(rotation=45)    # x축 글자 회전하기
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# scatter plot
df_auto = pd.read_excel('./dataset/auto-mpg.xlsx',engine = 'openpyxl')
x = df_auto.mpg
y = df_auto.weight
plt.figure(figsize=(10,6))
plt.scatter(x,y,color='skyblue')
plt.xlabel('mpg',size=20)
plt.ylabel('weight',size=20)
# Out:
# Text(0, 0.5, 'weight')

# %%
# histogram
plt.hist(x,bins=20,color='gray')
# Out:
# (array([ 3., 10., 40., 38., 36., 37., 30., 31., 21., 33., 24., 24., 20.,
#         18., 13.,  9.,  4.,  1.,  5.,  1.]),
#  array([ 9.  , 10.88, 12.76, 14.64, 16.52, 18.4 , 20.28, 22.16, 24.04,
#         25.92, 27.8 , 29.68, 31.56, 33.44, 35.32, 37.2 , 39.08, 40.96,
#         42.84, 44.72, 46.6 ]),
#  <BarContainer object of 20 artists>)

# %%
fig = plt.figure(figsize=(12,8))
# figure가 2 x 2 크기이고 4개의 서브플롯
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)
np.random.seed(0)
ax1.hist(np.random.randn(10000),bins=20, color='k', alpha=0.7)  # 정규분포
ax2.hist(np.random.rand(10000),bins=20,color='k',alpha=0.3)   # 균일분포
ax3.plot(np.random.randn(50).cumsum(),'k--')  # 누적
ax4.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))

# %%
# [과제] 히스토그램, 선, 막대, 산점도 그래프 4개를 서브플롯으로 출력하세요.

# %%
df_ep = pd.read_excel('./dataset/df_ep.xlsx')
df_ep.set_index('year',inplace=True)
fig = plt.figure(figsize=(10,6))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

plt.xlabel
ax1.plot(df_ep.south,color='lightskyblue',marker='^',markersize=3)
ax2.bar(df_ep.index,df_ep.south,color='lightcoral',width=0.8,alpha=0.8)
ax3.hist(df_ep.south,bins=len(df_ep),color='orange',alpha=0.5)
ax4.scatter(df_ep.index,df_ep.south,color='mediumseagreen',alpha=0.7,marker='h')

# %%
import math
fig = plt.figure(figsize=(12,8))

ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

#=======================히스토그램=======================
num=np.zeros(600)
for i in range(100): num[i]=np.random.randint(1,45)
for i in range(100,250): num[i]=np.random.randint(45,75)
for i in range(250,600): num[i]=np.random.randint(75,100)    
ax1.hist(num, bins = 50, color ='k',alpha = 0.7) 
#=======================선=======================
x=np.arange(360)
y=[]
for i in x:
    a=math.cos(math.pi*(i/180))
    y.append(a)    
ax2.plot(x,y,  color = 'k')
#=======================막대=======================
ax3.bar(x,y,width=0.8)
#=======================산점도=======================
sc_x=np.arange(30)
sc_y=np.full(30,51)
ax4.scatter(sc_x,sc_y)

# %%
import matplotlib.pyplot as plt
import numpy as np
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

x = [0,1,3,4,6,7,7,6,5,4,3,0,-3,-4,-5,-6,-7,-7,-6,-4,-3,-1,0]
y = [4,6,7,7,6,3,0,-2,-3,-4,-5,-8,-5,-4,-3,-2,0,3,6,7,7,6,4]

def heart(axis):
    axis.plot(x,y,'red',linestyle=':')

def loveu(axis,color):
    x1 = [0,1,3,4,6,7,7,6,5,4,3,0,-3,-4,-5,-6,-7,-7,-6,-4,-3,-1,0]
    y1 = [4,6,7,7,6,3,0,-2,-3,-4,-5,-8,-5,-4,-3,-2,0,3,6,7,7,6,4] ; axis.plot(x1,y1,color,linestyle=':')
    x2 = [-6,-6,-4]
    y2 = [3,0,0] ; axis.plot(x2,y2,color,linestyle=':')
    x3 = [-2,-3,-3,-2,-1,-1,-2]
    y3 = [3,2,1,0,1,2,3] ; axis.plot(x3,y3,color,linestyle=':')
    x4 = [1,2,3]
    y4 = [3,0,3] ; axis.plot(x4,y4,color,linestyle=':')
    x5 = [6,4,4,6,4,4,6]
    y5 = [3,3,2,2,2,0,0] ; axis.plot(x5,y5,color,linestyle=':')
    x6 = [-4,-3,-3,-3,-2]
    y6 = [-1,-3,-4,-3,-1] ; axis.plot(x6,y6,color,linestyle=':')
    x7 = [0,-1,-1,0,1,1,0]
    y7 = [-1,-2,-3,-4,-3,-2,-1] ; axis.plot(x7,y7,color,linestyle=':')
    x8 = [2,2,4,4]
    y8 = [-1,-4,-4,-1] ; axis.plot(x8,y8,color,linestyle=':')

def class601(axis):
    x9 = [-3,-7,-7,-3,-3,-7]
    y9 = [3,3,-3,-3,0,0] ; axis.plot(x9,y9,'black',linestyle=':')
    x10 = [-2,-2,2,2,-2]
    y10 = [3,-3,-3,3,3] ; axis.plot(x10,y10,'black',linestyle=':')
    x11 = [7,7]
    y11 = [3,-3] ; axis.plot(x11,y11,'black',linestyle=':')

class601(ax1)
heart(ax2)
heart(ax3)
loveu(ax3,'red')
heart(ax4)
loveu(ax4,'black')
ax4.fill(x,y,'r',alpha=0.5)

# %%
from numpy.random import randn
plt.figure(figsize=(10,6))
plt.plot(randn(30).cumsum(), linestyle='dashed',color='b',marker='o')

# %%
t3 = pd.read_csv('./dataset/titanic3.csv')
t3.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Q. t3에서 age열을 범주화한 후 age_cat 열을 추가하세요.

# %%
def catage(age):
    cat = ''
    if age<10: cat='Child'
    elif age<20: cat='Teen'
    elif age<30: cat='20s'
    elif age<40: cat='30s'
    elif age<50: cat='40s'
    elif age<60: cat='50s'
    else: cat='Eldery'
    return cat
t3['age_cat'] = t3.age.apply(lambda x:catage(x))
t3[['age','age_cat']].head()
# Out:
#      age age_cat
# 0  29.00     20s
# 1   0.92   Child
# 2   2.00   Child
# 3  30.00     30s
# 4  25.00     20s

# %%
t3['Ratio'] = 1
df_age_cat = t3.groupby('age_cat').sum()
print(df_age_cat.head())

df_age_cat.Ratio.plot(kind='pie',
                     figsize=(10,8),
                     autopct='%.2f%%',
                     startangle=0)
plt.title('Age Category',size=20)
plt.axis('equal')
plt.legend(labels=df_age_cat.index, loc='best')
# Out:
#          pclass  survived      age  sibsp  parch       fare    body  Ratio
# age_cat
# 20s         838       127  8402.00    112     77  9198.3038  5125.0    344
# 30s         488        98  7855.50     80     73  9578.5332  5020.0    232
# 40s         250        52  5958.50     50     68  5723.5168  3429.0    135
# 50s         101        32  3751.50     29     21  4384.9541  1889.0     70
# Child       216        50   330.17    135    114  2403.4248     4.0     82

# %%
# 물고기 종류별 몸 길이 데이터
import seaborn as sns

df = pd.read_csv('dataset/4_fm2.csv')
# 종류별 몸 길이 데이터 추출
length_a = df.query('species=="A"')['length']
length_b = df.query('species=="B"')['length']
sns.histplot(length_a,color='gray',kde=True)
# Out:
# <AxesSubplot:xlabel='length', ylabel='Count'>

# %%
df
# Out:
#    species  length
# 0        A       2
# 1        A       3
# 2        A       3
# 3        A       4
# 4        A       4
# 5        A       4
# 6        A       4
# 7        A       5
# 8        A       5
# 9        A       6
# 10       B       5
# 11       B       6
# 12       B       6
# 13       B       7
# 14       B       7
# 15       B       7
# 16       B       7
# 17       B       8
# 18       B       8
# 19       B       9

# %%
sns.boxplot(x='species',y='length',data=df,color='skyblue')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
# 바이올린 플롯
sns.violinplot(x='species',y='length',data=df,color='skyblue')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
df1 = df.copy()
df1.iloc[5,1] = 10
df1.iloc[10,1] = 2

# %%
# [과제] df1으로 박스플롯을 확인한 후 이상치를 구하세요.
sns.boxplot(x='species',y='length',data=df1,color='skyblue')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
Q1 = df1.species.quantile(.25)
Q3 = df1.species.describe()['75%']
IQR = Q3 - Q1
uw_check = Q3 + 1.5 * IQR
print(uw_check,'\n')
print(df1.species.sort_values(ascending=False)[:5],'\n')
print('uw 13200을 벗어나는 값 선택:')
df1.species.loc[df1.species > Q3 + 1.5 * IQR]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6700/3958647157.py in <module>
# ----> 1 Q1 = df1.species.quantile(.25)
#       2 Q3 = df1.species.describe()['75%']
#       3 IQR = Q3 - Q1
#       4 uw_check = Q3 + 1.5 * IQR
#       5 print(uw_check,'\n')
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2446         df = self.to_frame()
#    2447
# -> 2448         result = df.quantile(q=q, interpolation=interpolation, numeric_only=False)
#    2449         if result.ndim == 2:
#    2450             result = result.iloc[:, 0]
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#   10291         if not is_list_like(q):
#   10292             # BlockManager.quantile expects listlike, so we wrap and unwrap here
# > 10293             res = self.quantile(
#   10294                 [q], axis=axis, numeric_only=numeric_only, interpolation=interpolation
#   10295             )
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\frame.py in quantile(self, q, axis, numeric_only, interpolation)
#   10310             return self._constructor_sliced([], index=cols, name=q, dtype=np.float64)
#   10311
# > 10312         res = data._mgr.quantile(qs=q, axis=1, interpolation=interpolation)
#   10313
#   10314         result = self._constructor(res)
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\internals\managers.py in quantile(self, qs, axis, interpolation)
#    1343         new_axes[1] = Float64Index(qs)
#    1344
# -> 1345         blocks = [
#    1346             blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1347             for blk in self.blocks
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\internals\managers.py in <listcomp>(.0)
#    1344
#    1345         blocks = [
# -> 1346             blk.quantile(axis=axis, qs=qs, interpolation=interpolation)
#    1347             for blk in self.blocks
#    1348         ]
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\internals\blocks.py in quantile(self, qs, interpolation, axis)
#    1321         assert is_list_like(qs)  # caller is responsible for this
#    1322
# -> 1323         result = quantile_compat(self.values, np.asarray(qs._values), interpolation)
#    1324         return new_block(result, placement=self._mgr_locs, ndim=2)
#    1325
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\array_algos\quantile.py in quantile_compat(values, qs, interpolation)
#      36         fill_value = na_value_for_dtype(values.dtype, compat=False)
#      37         mask = isna(values)
# ---> 38         return _quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      39     else:
#      40         # In general we don't want to import from arrays here;
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\array_algos\quantile.py in _quantile_with_mask(values, mask, fill_value, qs, interpolation)
#      98     else:
#      99         # asarray needed for Sparse, see GH#24600
# --> 100         result = nanpercentile(
#     101             values,
#     102             np.array(qs) * 100,
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\pandas\core\nanops.py in nanpercentile(values, q, na_value, mask, interpolation)
#    1721         return result
#    1722     else:
# -> 1723         return np.percentile(values, q, axis=1, interpolation=interpolation)
#    1724
#    1725
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\numpy\lib\function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3865     if not _quantile_is_valid(q):
#    3866         raise ValueError("Percentiles must be in the range [0, 100]")
# -> 3867     return _quantile_unchecked(
#    3868         a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3869
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\numpy\lib\function_base.py in _quantile_unchecked(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3984                         interpolation='linear', keepdims=False):
#    3985     """Assumes that q is in [0, 1], and is an ndarray"""
# -> 3986     r, k = _ureduce(a, func=_quantile_ureduce_func, q=q, axis=axis, out=out,
#    3987                     overwrite_input=overwrite_input,
#    3988                     interpolation=interpolation)
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\numpy\lib\function_base.py in _ureduce(a, func, **kwargs)
#    3562         keepdim = (1,) * a.ndim
#    3563
# -> 3564     r = func(a, **kwargs)
#    3565     return r, keepdim
#    3566
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\numpy\lib\function_base.py in _quantile_ureduce_func(***failed resolving arguments***)
#    4110         x_above = take(ap, indices_above, axis=0)
#    4111
# -> 4112         r = _lerp(x_below, x_above, weights_above, out=out)
#    4113
#    4114     # if any slice contained a nan, then all results on that slice are also nan
#
# C:\sw\Anaconda3\envs\cakd5\lib\site-packages\numpy\lib\function_base.py in _lerp(a, b, t, out)
#    4007 def _lerp(a, b, t, out=None):
#    4008     """ Linearly interpolate from a to b by a factor of t """
# -> 4009     diff_b_a = subtract(b, a)
#    4010     # asanyarray is a stop-gap until gh-13105
#    4011     lerp_interpolation = asanyarray(add(a, diff_b_a*t, out=out))
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
cov_df = pd.read_csv('dataset/4_cov.csv')
sns.jointplot(cov_df.x,cov_df.y,kind='reg')

# %%
df_auto = pd.read_excel('dataset/auto-mpg.xlsx')
df_auto
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
sns.lmplot(x='mpg',y='weight',data=df_auto,scatter_kws={'color':'skyblue'},line_kws={'color':'green'})

# %%
sns.regplot(x='mpg',y='weight',data=df_auto,fit_reg=True)
# Out:
# <AxesSubplot:xlabel='mpg', ylabel='weight'>

# %%
df2= df_auto[['mpg','cylinders','weight']]
sns.pairplot(df2)
sns.set_palette('gray') # 색 변환

# %%
import matplotlib.pyplot as plt
tdf = sns.load_dataset('titanic')
plt.figure(figsize=(8,6))
sns.heatmap(tdf[['pclass','age','fare','survived']].corr(),annot=True)
plt.title('Heatmap of the Dataset', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Heatmap of the Dataset')

# %%
table = tdf.pivot_table(index=['sex'],columns=['class'],values=['survived'],aggfunc='mean')
table
# Out:
#         survived
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
plt.figure(figsize=(8,6))
sns.heatmap(table,
           annot=True,fmt='f',
           cmap='YlGnBu',
           linewidth=.5,
           cbar=True)
# Out:
# <AxesSubplot:xlabel='None-class', ylabel='sex'>
